# %%
from main import find_path

find_path("maze_map0.txt", "DFS")
find_path("maze_map0.txt", "BFS")
find_path("maze_map0.txt", "GBFS", "euclidean_distance")
find_path("maze_map0.txt", "A*", "euclidean_distance")
find_path("maze_map0.txt", "GBFS", "manhattan_distances")
find_path("maze_map0.txt", "A*", "manhattan_distances")
# Out:
# So vong lap DFS:  290
# Cost:  124
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap BFS:  208
# Cost:  48
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap GBFS:  162
# Cost:  88
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap A*:  138
# Cost:  48
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap GBFS:  79
# Cost:  48
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap A*:  104
# Cost:  48
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)

# %%
from main import find_path

find_path("maze_map1.txt", "DFS")
find_path("maze_map1.txt", "BFS")
find_path("maze_map1.txt", "GBFS", "euclidean_distance")
find_path("maze_map1.txt", "A*", "euclidean_distance")
find_path("maze_map1.txt", "GBFS", "manhattan_distances")
find_path("maze_map1.txt", "A*", "manhattan_distances")
# Out:
# So vong lap DFS:  528
# Cost:  138
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap BFS:  348
# Cost:  42
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap GBFS:  2286
# Cost:  56
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap A*:  329
# Cost:  42
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap GBFS:  42
# Cost:  42
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap A*:  348
# Cost:  42
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)

# %%
from main import find_path

find_path("maze_map2.txt", "DFS")
find_path("maze_map2.txt", "BFS")
find_path("maze_map2.txt", "GBFS", "euclidean_distance")
find_path("maze_map2.txt", "A*", "euclidean_distance")
find_path("maze_map2.txt", "GBFS", "manhattan_distances")
find_path("maze_map2.txt", "A*", "manhattan_distances")
# Out:
# So vong lap DFS:  543
# Cost:  202
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (18, 39)
#
#
# So vong lap BFS:  464
# Cost:  86
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (18, 39)
#
#
# So vong lap GBFS:  845
# Cost:  96
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (18, 39)
#
#
# So vong lap A*:  380
# Cost:  86
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (18, 39)
#
#
# So vong lap GBFS:  1507
# Cost:  96
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (18, 39)
#
#
# So vong lap A*:  318
# Cost:  86
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (18, 39)

# %%
from main import find_path

find_path("maze_map3.txt", "DFS")
find_path("maze_map3.txt", "BFS")
find_path("maze_map3.txt", "GBFS", "euclidean_distance")
find_path("maze_map3.txt", "A*", "euclidean_distance")
find_path("maze_map3.txt", "GBFS", "manhattan_distances")
find_path("maze_map3.txt", "A*", "manhattan_distances")
# Out:
# So vong lap DFS:  90
# Cost:  73
# Starting point (x, y) = (8, 18)
# Ending point (x, y) = (4, 0)
#
#
# So vong lap BFS:  107
# Cost:  25
# Starting point (x, y) = (8, 18)
# Ending point (x, y) = (4, 0)
#
#
# So vong lap GBFS:  33
# Cost:  25
# Starting point (x, y) = (8, 18)
# Ending point (x, y) = (4, 0)
#
#
# So vong lap A*:  76
# Cost:  25
# Starting point (x, y) = (8, 18)
# Ending point (x, y) = (4, 0)
#
#
# So vong lap GBFS:  38
# Cost:  25
# Starting point (x, y) = (8, 18)
# Ending point (x, y) = (4, 0)
#
#
# So vong lap A*:  75
# Cost:  25
# Starting point (x, y) = (8, 18)
# Ending point (x, y) = (4, 0)

# %%
from main import find_path

find_path("maze_map4.txt", "DFS")
find_path("maze_map4.txt", "BFS")
find_path("maze_map4.txt", "GBFS", "euclidean_distance")
find_path("maze_map4.txt", "A*", "euclidean_distance")
find_path("maze_map4.txt", "GBFS", "manhattan_distances")
find_path("maze_map4.txt", "A*", "manhattan_distances")
# Out:
# So vong lap DFS:  255
# Cost:  195
# Starting point (x, y) = (9, 12)
# Ending point (x, y) = (18, 23)
#
#
# So vong lap BFS:  283
# Cost:  143
# Starting point (x, y) = (9, 12)
# Ending point (x, y) = (18, 23)
#
#
# So vong lap GBFS:  4955
# Cost:  151
# Starting point (x, y) = (9, 12)
# Ending point (x, y) = (18, 23)
#
#
# So vong lap A*:  280
# Cost:  143
# Starting point (x, y) = (9, 12)
# Ending point (x, y) = (18, 23)
#
#
# So vong lap GBFS:  4322
# Cost:  149
# Starting point (x, y) = (9, 12)
# Ending point (x, y) = (18, 23)
#
#
# So vong lap A*:  264
# Cost:  143
# Starting point (x, y) = (9, 12)
# Ending point (x, y) = (18, 23)

# %%
from main import find_path

find_path("maze_map5.txt", "eat_points")
find_path("maze_map6.txt", "eat_points")
# Out:
# Cost:  42
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
# Bonus point at position (x, y) = (1, 19) with point -25
# Bonus point at position (x, y) = (9, 6) with point -4
#
#
# Cost:  -2
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
# Bonus point at position (x, y) = (2, 23) with point -10
# Bonus point at position (x, y) = (4, 5) with point -4
# Bonus point at position (x, y) = (7, 22) with point -20
# Bonus point at position (x, y) = (9, 15) with point -15
# Bonus point at position (x, y) = (13, 10) with point -30

# %%
from main import find_path

find_path("maze_map7.txt", "eat_points")
# Out:
# Cost:  78
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (18, 39)
# Bonus point at position (x, y) = (10, 1) with point -10
# Bonus point at position (x, y) = (18, 1) with point -10
# Bonus point at position (x, y) = (1, 3) with point -10
# Bonus point at position (x, y) = (1, 6) with point -10
# Bonus point at position (x, y) = (1, 24) with point -10
# Bonus point at position (x, y) = (17, 10) with point -10
# Bonus point at position (x, y) = (18, 13) with point -10
# Bonus point at position (x, y) = (12, 27) with point -10
# Bonus point at position (x, y) = (1, 35) with point -10
# Bonus point at position (x, y) = (8, 35) with point -10

# %%
from main import find_path

find_path("maze_map8.txt", "DFS_T")
find_path("maze_map8.txt", "BFS_T")
# Out:
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
#
#
# So vong lap BFS:  130
# Starting point (x, y) = (1, 1)
# Ending point (x, y) = (13, 30)
